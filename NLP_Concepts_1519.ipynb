# %% [markdown]
# <a href="https://colab.research.google.com/github/sindhura-nk/AI-Projects---1519/blob/main/NLP_Concepts_1519.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## NLP: Natural Language Processing
# ### Two sections:
#     Natural Language Understanding(model understanding)
#     Natural Language Generation(model generates new content)
#
# ## Text Understanding:
# ### Text Cleaning:
#     converting the text content into lowercase
#     removal of punctuation marks, special characters
#     removal of stopwords
#
#     Stopwords:Give all the data to the model , this increases the complexity. To avoid that, we can remove the stopwords.
#
#     Words that are meaningful for sentence formation but not really necessary for our model to learn are referred as stop words.
#     Example: a,again,against,are,and ....
#
# ### Tokenization:
#     Converting the words into characters representing tokens
#     Converting the sentences into words representing  tokens
#     Converting the paragraphs into sentences representing tokens
#
#     Example: ["beautiful","easy","easily","walked","walk","walking"] : total words machine has to learn - 6
#     [beauty,easy,easy,walk,walk,walk] - total words machine has to learn - 3
#
#
# ### Stemming: Converts the word to its root form
#     It removes prefix/suffix so that root form of the word is resulted.
#     happiness : happy
#     given : give
#
#     3 most popular stemmer types:
#     Portal Stemmer
#     Lancaster Stemmer
#     Snowball Stemmer
#
#     Stemming techniques are resulting in a word that doesn't exist
#     happiness: happi
#     given : give
#     easily : easili
#
#
# ### Lemmitization: Converts the word into base form. It uses the dictionary format. With the help of POS tags(parts of speech tags)
#     happiness: happiness
#     given: give
#
#     POS tags: Parts of Speech
#
# ### Named Entity Recognition : (NER): Entities - you can image this as a set of entities/categories.
#     Oraganization
#     Location
#     Date/Time
#     Person
#     Example: "Sindhura works in 3RI technologies located at Pimple Saudagar. She has celebrated Ganesh Chaturthi on 27th August".
#     Sindhura,She - Person
#     3RI Technologies - Organization
#     Pimple Saudagar - Location
#     Date - 27th August
#
# ### Vectorizer
#
#     Count Vectorizer(Bag of Words)
#
#     TFIDF
#
#     Word based vectors are generated that are provided to model for model training

# %% [markdown]
# ## NLTK - Natural Language Tool Kit is a library that contains all the necessary packages required to handle NLU

# %%
pip install nltk

# %%
import os
import nltk
import nltk.corpus
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %%
os.listdir(nltk.data.find("corpora"))
# Out:
# ['genesis',
#  'gazetteers',
#  'words.zip',
#  'treebank.zip',
#  'subjectivity.zip',
#  'nps_chat',
#  'paradigms',
#  'conll2002.zip',
#  'webtext.zip',
#  'extended_omw.zip',
#  'webtext',
#  'smultron.zip',
#  'crubadan.zip',
#  'pl196x',
#  'problem_reports',
#  'cmudict',
#  'paradigms.zip',
#  'qc.zip',
#  'wordnet.zip',
#  'chat80',
#  'propbank.zip',
#  'machado.zip',
#  'shakespeare',
#  'sentence_polarity.zip',
#  'kimmo',
#  'smultron',
#  'alpino',
#  'shakespeare.zip',
#  'cess_esp.zip',
#  'pros_cons.zip',
#  'biocreative_ppi',
#  'rte.zip',
#  'mac_morpho.zip',
#  'ieer.zip',
#  'brown_tei',
#  'nombank.1.0.zip',
#  'treebank',
#  'bcp47.zip',
#  'ycoe',
#  'nonbreaking_prefixes.zip',
#  'twitter_samples',
#  'verbnet3',
#  'sentiwordnet.zip',
#  'senseval.zip',
#  'gazetteers.zip',
#  'names',
#  'crubadan',
#  'reuters.zip',
#  'comparative_sentences',
#  'movie_reviews.zip',
#  'nonbreaking_prefixes',
#  'pe08',
#  'state_union.zip',
#  'pil.zip',
# ...

# %%
from nltk.corpus import indian
indian.words()
# Out:
# ['মহিষের', 'সন্তান', ':', 'তোড়া', 'উপজাতি', '৷', ...]

# %%
from nltk.corpus import indian
indian.fileids()
# Out:
# ['bangla.pos', 'hindi.pos', 'marathi.pos', 'telugu.pos']

# %%
hindi = indian.words("hindi.pos")
hindi
# Out:
# ['पूर्ण', 'प्रतिबंध', 'हटाओ', ':', 'इराक', 'संयुक्त', ...]

# %%
marathi = indian.words("marathi.pos")
marathi
# Out:
# ["''", 'सनातनवाद्यांनी', 'व', 'प्रतिगाम्यांनी', 'समाज', ...]

# %%
from nltk.corpus import swadesh
swadesh.words()[:10]
# Out:
# ['я', 'ты', 'ён', 'мы', 'вы', 'яны', 'гэта', 'гэны', 'тут', 'там']

# %%
swadesh.fileids()[:10]
# Out:
# ['be', 'bg', 'bs', 'ca', 'cs', 'cu', 'de', 'en', 'es', 'fr']

# %%
sw=swadesh.words('en')
sw[:10]
# Out:
# ['I',
#  'you (singular), thou',
#  'he',
#  'we',
#  'you (plural)',
#  'they',
#  'this',
#  'that',
#  'here',
#  'there']

# %%
from nltk.corpus import gutenberg
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
hamlet = gutenberg.words("shakespeare-hamlet.txt")
hamlet
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
hamlet[:500]
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
for word in hamlet[:500]:
  print(word,sep=" ",end=" ")
# Out:
# [ The Tragedie of Hamlet by William Shakespeare 1599 ] Actus Primus . Scoena Prima . Enter Barnardo and Francisco two Centinels . Barnardo . Who ' s there ? Fran . Nay answer me : Stand & vnfold your selfe Bar . Long liue the King Fran . Barnardo ? Bar . He Fran . You come most carefully vpon your houre Bar . ' Tis now strook twelue , get thee to bed Francisco Fran . For this releefe much thankes : ' Tis bitter cold , And I am sicke at heart Barn . Haue you had quiet Guard ? Fran . Not a Mouse stirring Barn . Well , goodnight . If you do meet Horatio and Marcellus , the Riuals of my Watch , bid them make hast . Enter Horatio and Marcellus . Fran . I thinke I heare them . Stand : who ' s there ? Hor . Friends to this ground Mar . And Leige - men to the Dane Fran . Giue you good night Mar . O farwel honest Soldier , who hath relieu ' d you ? Fra . Barnardo ha ' s my place : giue you goodnight . Exit Fran . Mar . Holla Barnardo Bar . Say , what is Horatio there ? Hor . A peece of him Ba
# ...

# %%
data = """
Data analysis is the process of inspecting, cleansing, transforming, and modeling data with the goal of discovering useful information, informing conclusions,
and supporting decision-making.[1] Data analysis has multiple facets and approaches, encompassing diverse techniques under a variety of names, and is used in different business, science, and social science domains.[2]
 In today's business world, data analysis plays a role in making decisions more scientific and helping businesses operate more effectively.
"""

# %% [markdown]
# ## Text cleaning

# %%
import re
data = data.lower()
pattern = r"[^a-z. ]"
data_new = re.sub(pattern,"",data)
data_new
# Out:
# 'data analysis is the process of inspecting cleansing transforming and modeling data with the goal of discovering useful information informing conclusionsand supporting decisionmaking. data analysis has multiple facets and approaches encompassing diverse techniques under a variety of names and is used in different business science and social science domains. in todays business world data analysis plays a role in making decisions more scientific and helping businesses operate more effectively.'

# %% [markdown]
# ## Sentence TOkenize

# %%
from nltk.tokenize import sent_tokenize
sent_tokens = sent_tokenize(data_new)
sent_tokens
# Out:
# ['data analysis is the process of inspecting cleansing transforming and modeling data with the goal of discovering useful information informing conclusionsand supporting decisionmaking.',
#  'data analysis has multiple facets and approaches encompassing diverse techniques under a variety of names and is used in different business science and social science domains.',
#  'in todays business world data analysis plays a role in making decisions more scientific and helping businesses operate more effectively.']

# %%
len(sent_tokens)
# Out:
# 3

# %% [markdown]
# ## Word Tokenize

# %%
from nltk.tokenize import word_tokenize
word_sent_tokens = []
for i in sent_tokens:
  word_sent_tokens.append(word_tokenize(i))
print(word_sent_tokens)
# Out:
# [['data', 'analysis', 'is', 'the', 'process', 'of', 'inspecting', 'cleansing', 'transforming', 'and', 'modeling', 'data', 'with', 'the', 'goal', 'of', 'discovering', 'useful', 'information', 'informing', 'conclusionsand', 'supporting', 'decisionmaking', '.'], ['data', 'analysis', 'has', 'multiple', 'facets', 'and', 'approaches', 'encompassing', 'diverse', 'techniques', 'under', 'a', 'variety', 'of', 'names', 'and', 'is', 'used', 'in', 'different', 'business', 'science', 'and', 'social', 'science', 'domains', '.'], ['in', 'todays', 'business', 'world', 'data', 'analysis', 'plays', 'a', 'role', 'in', 'making', 'decisions', 'more', 'scientific', 'and', 'helping', 'businesses', 'operate', 'more', 'effectively', '.']]

# %%
from nltk.tokenize import word_tokenize
word_tokens = word_tokenize(data_new)
word_tokens # these tokens are generated by unigrams - 1gram- 1word token is generated
# Out:
# ['data',
#  'analysis',
#  'is',
#  'the',
#  'process',
#  'of',
#  'inspecting',
#  'cleansing',
#  'transforming',
#  'and',
#  'modeling',
#  'data',
#  'with',
#  'the',
#  'goal',
#  'of',
#  'discovering',
#  'useful',
#  'information',
#  'informing',
#  'conclusionsand',
#  'supporting',
#  'decisionmaking',
#  '.',
#  'data',
#  'analysis',
#  'has',
#  'multiple',
#  'facets',
#  'and',
#  'approaches',
#  'encompassing',
#  'diverse',
#  'techniques',
#  'under',
#  'a',
#  'variety',
#  'of',
#  'names',
#  'and',
#  'is',
#  'used',
#  'in',
#  'different',
#  'business',
#  'science',
#  'and',
#  'social',
#  'science',
#  'domains',
#  '.',
#  'in',
#  'todays',
#  'business',
#  'world',
#  'data',
#  'analysis',
#  'plays',
#  'a',
#  'role',
#  'in',
#  'making',
#  'decisions',
#  'more',
#  'scientific',
#  'and',
#  'helping',
#  'businesses',
#  'operate',
#  'more',
#  'effectively',
#  '.']

# %%
len(word_tokens)

# %% [markdown]
# ## Bigrams(2) , Trigrams(3), Ngrams(n number of words)

# %%
# bi_tokens = list(nltk.bigrams(unigram tokens)) => unigram tokens = word_tokenize(data)
bi_tokens = list(nltk.bigrams(word_tokens))
bi_tokens
# Out:
# [('data', 'analysis'),
#  ('analysis', 'is'),
#  ('is', 'the'),
#  ('the', 'process'),
#  ('process', 'of'),
#  ('of', 'inspecting'),
#  ('inspecting', 'cleansing'),
#  ('cleansing', 'transforming'),
#  ('transforming', 'and'),
#  ('and', 'modeling'),
#  ('modeling', 'data'),
#  ('data', 'with'),
#  ('with', 'the'),
#  ('the', 'goal'),
#  ('goal', 'of'),
#  ('of', 'discovering'),
#  ('discovering', 'useful'),
#  ('useful', 'information'),
#  ('information', 'informing'),
#  ('informing', 'conclusionsand'),
#  ('conclusionsand', 'supporting'),
#  ('supporting', 'decisionmaking'),
#  ('decisionmaking', '.'),
#  ('.', 'data'),
#  ('data', 'analysis'),
#  ('analysis', 'has'),
#  ('has', 'multiple'),
#  ('multiple', 'facets'),
#  ('facets', 'and'),
#  ('and', 'approaches'),
#  ('approaches', 'encompassing'),
#  ('encompassing', 'diverse'),
#  ('diverse', 'techniques'),
#  ('techniques', 'under'),
#  ('under', 'a'),
#  ('a', 'variety'),
#  ('variety', 'of'),
#  ('of', 'names'),
# ...

# %%
tri_tokens = list(nltk.trigrams(word_tokens))
tri_tokens
# Out:
# [('data', 'analysis', 'is'),
#  ('analysis', 'is', 'the'),
#  ('is', 'the', 'process'),
#  ('the', 'process', 'of'),
#  ('process', 'of', 'inspecting'),
#  ('of', 'inspecting', 'cleansing'),
#  ('inspecting', 'cleansing', 'transforming'),
#  ('cleansing', 'transforming', 'and'),
#  ('transforming', 'and', 'modeling'),
#  ('and', 'modeling', 'data'),
#  ('modeling', 'data', 'with'),
#  ('data', 'with', 'the'),
#  ('with', 'the', 'goal'),
#  ('the', 'goal', 'of'),
#  ('goal', 'of', 'discovering'),
#  ('of', 'discovering', 'useful'),
#  ('discovering', 'useful', 'information'),
#  ('useful', 'information', 'informing'),
#  ('information', 'informing', 'conclusionsand'),
#  ('informing', 'conclusionsand', 'supporting'),
#  ('conclusionsand', 'supporting', 'decisionmaking'),
#  ('supporting', 'decisionmaking', '.'),
#  ('decisionmaking', '.', 'data'),
#  ('.', 'data', 'analysis'),
#  ('data', 'analysis', 'has'),
#  ('analysis', 'has', 'multiple'),
#  ('has', 'multiple', 'facets'),
# ...

# %%
n_tokens = list(nltk.ngrams(word_tokens,n=5))
n_tokens
# Out:
# [('data', 'analysis', 'is', 'the', 'process'),
#  ('analysis', 'is', 'the', 'process', 'of'),
#  ('is', 'the', 'process', 'of', 'inspecting'),
#  ('the', 'process', 'of', 'inspecting', 'cleansing'),
#  ('process', 'of', 'inspecting', 'cleansing', 'transforming'),
#  ('of', 'inspecting', 'cleansing', 'transforming', 'and'),
#  ('inspecting', 'cleansing', 'transforming', 'and', 'modeling'),
#  ('cleansing', 'transforming', 'and', 'modeling', 'data'),
#  ('transforming', 'and', 'modeling', 'data', 'with'),
#  ('and', 'modeling', 'data', 'with', 'the'),
#  ('modeling', 'data', 'with', 'the', 'goal'),
#  ('data', 'with', 'the', 'goal', 'of'),
#  ('with', 'the', 'goal', 'of', 'discovering'),
#  ('the', 'goal', 'of', 'discovering', 'useful'),
#  ('goal', 'of', 'discovering', 'useful', 'information'),
#  ('of', 'discovering', 'useful', 'information', 'informing'),
#  ('discovering', 'useful', 'information', 'informing', 'conclusionsand'),
# ...

# %% [markdown]
# ## Frequency Distribution

# %%
word_tokens
# Out:
# ['data',
#  'analysis',
#  'is',
#  'the',
#  'process',
#  'of',
#  'inspecting',
#  'cleansing',
#  'transforming',
#  'and',
#  'modeling',
#  'data',
#  'with',
#  'the',
#  'goal',
#  'of',
#  'discovering',
#  'useful',
#  'information',
#  'informing',
#  'conclusionsand',
#  'supporting',
#  'decisionmaking',
#  '.',
#  'data',
#  'analysis',
#  'has',
#  'multiple',
#  'facets',
#  'and',
#  'approaches',
#  'encompassing',
#  'diverse',
#  'techniques',
#  'under',
#  'a',
#  'variety',
#  'of',
#  'names',
#  'and',
#  'is',
#  'used',
#  'in',
#  'different',
#  'business',
#  'science',
#  'and',
#  'social',
#  'science',
#  'domains',
#  '.',
#  'in',
#  'todays',
#  'business',
#  'world',
#  'data',
#  'analysis',
#  'plays',
#  'a',
#  'role',
#  'in',
#  'making',
#  'decisions',
#  'more',
#  'scientific',
#  'and',
#  'helping',
#  'businesses',
#  'operate',
#  'more',
#  'effectively',
#  '.']

# %%
from nltk.probability import FreqDist
fdst =FreqDist()

# %%
for word in word_tokens:
  fdst[word]+=1

# %%
fdst

# %%
fdst.most_common()
# Out:
# [('and', 5),
#  ('data', 4),
#  ('analysis', 3),
#  ('of', 3),
#  ('.', 3),
#  ('in', 3),
#  ('is', 2),
#  ('the', 2),
#  ('a', 2),
#  ('business', 2),
#  ('science', 2),
#  ('more', 2),
#  ('process', 1),
#  ('inspecting', 1),
#  ('cleansing', 1),
#  ('transforming', 1),
#  ('modeling', 1),
#  ('with', 1),
#  ('goal', 1),
#  ('discovering', 1),
#  ('useful', 1),
#  ('information', 1),
#  ('informing', 1),
#  ('conclusionsand', 1),
#  ('supporting', 1),
#  ('decisionmaking', 1),
#  ('has', 1),
#  ('multiple', 1),
#  ('facets', 1),
#  ('approaches', 1),
#  ('encompassing', 1),
#  ('diverse', 1),
#  ('techniques', 1),
#  ('under', 1),
#  ('variety', 1),
#  ('names', 1),
#  ('used', 1),
#  ('different', 1),
#  ('social', 1),
#  ('domains', 1),
#  ('todays', 1),
#  ('world', 1),
#  ('plays', 1),
#  ('role', 1),
#  ('making', 1),
#  ('decisions', 1),
#  ('scientific', 1),
#  ('helping', 1),
#  ('businesses', 1),
#  ('operate', 1),
#  ('effectively', 1)]

# %%
fdst.most_common()[:10]
# Out:
# [('and', 5),
#  ('data', 4),
#  ('analysis', 3),
#  ('of', 3),
#  ('.', 3),
#  ('in', 3),
#  ('is', 2),
#  ('the', 2),
#  ('a', 2),
#  ('business', 2)]

# %%
len(word_tokens)
# Out:
# 72

# %% [markdown]
# important keywords from above code cell are: data, analysis, business

# %% [markdown]
# ## Stopwords
# ![image.png](data:image/png;base64,...)

# %%
from nltk.corpus import stopwords
stopwords.fileids()
# Out:
# ['albanian',
#  'arabic',
#  'azerbaijani',
#  'basque',
#  'belarusian',
#  'bengali',
#  'catalan',
#  'chinese',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hebrew',
#  'hinglish',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'tamil',
#  'turkish',
#  'uzbek']

# %%
len(stopwords.fileids())
# Out:
# 33

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english') # mention the language
stop
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
len(stop)
# Out:
# 198

# %% [markdown]
# ##Word cloud

# %% [markdown]
# ## VIsualzie and see how many stopwords are present in word tokens

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
cloud=WordCloud(stopwords=stop,max_words=25).generate(str(word_tokens))
plt.figure(figsize=(10,10))
plt.imshow(cloud)
plt.show()

# %% [markdown]
# ## Removal of stopwords

# %%
len(word_tokens)

# %%
print(word_tokens[:50])

# %%
stop[:10]
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
filtered_words = []
for word in word_tokens:
  if word not in stop:
    filtered_words.append(word)
print(filtered_words)
# Out:
# ['data', 'analysis', 'process', 'inspecting', 'cleansing', 'transforming', 'modeling', 'data', 'goal', 'discovering', 'useful', 'information', 'informing', 'conclusionsand', 'supporting', 'decisionmaking', '.', 'data', 'analysis', 'multiple', 'facets', 'approaches', 'encompassing', 'diverse', 'techniques', 'variety', 'names', 'used', 'different', 'business', 'science', 'social', 'science', 'domains', '.', 'todays', 'business', 'world', 'data', 'analysis', 'plays', 'role', 'making', 'decisions', 'scientific', 'helping', 'businesses', 'operate', 'effectively', '.']

# %%
len(word_tokens)
# Out:
# 72

# %%
len(filtered_words)
# Out:
# 50

# %% [markdown]
# ## Stemming

# %% [markdown]
# ### Porter Stemmer

# %%
from nltk.stem import PorterStemmer

words = ["easily","walking","happiness","given","marked","inspecting"]

ps = PorterStemmer()

ps_words = [ps.stem(word) for word in words]
ps_words
# Out:
# ['easili', 'walk', 'happi', 'given', 'mark', 'inspect']

# %% [markdown]
# ### Lancaster Stemmer

# %%
from nltk.stem import LancasterStemmer

words = ["easily","walking","happiness","given","marked","inspecting"]

ls = LancasterStemmer()

ls_words = [ls.stem(word) for word in words]
ls_words
# Out:
# ['easy', 'walk', 'happy', 'giv', 'mark', 'inspect']

# %% [markdown]
# ## Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer

words = ["easily","walking","happiness","given","marked","inspecting"]

ss = SnowballStemmer(language='english')

ss_words = [ss.stem(word) for word in words]
ss_words
# Out:
# ['easili', 'walk', 'happi', 'given', 'mark', 'inspect']

# %% [markdown]
# ## Lemmatization

# %%
from nltk.stem import WordNetLemmatizer

word_lem = WordNetLemmatizer()

words =["easily","walking","happiness","given","marked","inspecting"]

lemma_words = [word_lem.lemmatize(word) for word in words] # by default, wordnet lemmatizer considers noun as default parts of speech
lemma_words
# Out:
# ['easily', 'walking', 'happiness', 'given', 'marked', 'inspecting']

# %%
from nltk.stem import WordNetLemmatizer

word_lem = WordNetLemmatizer()

words =["easily","walking","happiness","given","marked","inspecting"]

lemma_words = [word_lem.lemmatize(word,pos='v') for word in words] # by default, wordnet lemmatizer considers noun as default parts of speech
lemma_words
# Out:
# ['easily', 'walk', 'happiness', 'give', 'mark', 'inspect']

# %% [markdown]
# ## Pos tags and text parsing
# ![image.png](data:image/png;base64,...)

# %%
print(filtered_words)
# Out:
# ['data', 'analysis', 'process', 'inspecting', 'cleansing', 'transforming', 'modeling', 'data', 'goal', 'discovering', 'useful', 'information', 'informing', 'conclusionsand', 'supporting', 'decisionmaking', '.', 'data', 'analysis', 'multiple', 'facets', 'approaches', 'encompassing', 'diverse', 'techniques', 'variety', 'names', 'used', 'different', 'business', 'science', 'social', 'science', 'domains', '.', 'todays', 'business', 'world', 'data', 'analysis', 'plays', 'role', 'making', 'decisions', 'scientific', 'helping', 'businesses', 'operate', 'effectively', '.']

# %%
from nltk import pos_tag
tags = [pos_tag([word]) for word in filtered_words]
tags
# Out:
# [[('data', 'NNS')],
#  [('analysis', 'NN')],
#  [('process', 'NN')],
#  [('inspecting', 'VBG')],
#  [('cleansing', 'VBG')],
#  [('transforming', 'VBG')],
#  [('modeling', 'VBG')],
#  [('data', 'NNS')],
#  [('goal', 'NN')],
#  [('discovering', 'VBG')],
#  [('useful', 'JJ')],
#  [('information', 'NN')],
#  [('informing', 'VBG')],
#  [('conclusionsand', 'NN')],
#  [('supporting', 'VBG')],
#  [('decisionmaking', 'VBG')],
#  [('.', '.')],
#  [('data', 'NNS')],
#  [('analysis', 'NN')],
#  [('multiple', 'NN')],
#  [('facets', 'NNS')],
#  [('approaches', 'NNS')],
#  [('encompassing', 'VBG')],
#  [('diverse', 'NN')],
#  [('techniques', 'NNS')],
#  [('variety', 'NN')],
#  [('names', 'NNS')],
#  [('used', 'VBN')],
#  [('different', 'JJ')],
#  [('business', 'NN')],
#  [('science', 'NN')],
#  [('social', 'JJ')],
#  [('science', 'NN')],
#  [('domains', 'NNS')],
#  [('.', '.')],
#  [('todays', 'NNS')],
#  [('business', 'NN')],
#  [('world', 'NN')],
#  [('data', 'NNS')],
#  [('analysis', 'NN')],
# ...

# %% [markdown]
# ## Vectorizer
#     1. Count Vectorizer- Bag of words
#     2. TFIDF - Term Frequency, Inverse Document Frequency

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
data_new

# %%
bow_content = cv.fit_transform([data_new]).toarray()
bow_content

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer()
tf.fit_transform([data_new]).toarray()

# %% [markdown]
# ## Text Parsing
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Shallow Parsing

# %%
pip install spacy

# %%
# !python -m spacy download en_core_web_sm

# %%
import spacy

# Load English pipeline
nlp = spacy.load("en_core_web_sm")

data = """
Data analysis is the process of inspecting, cleansing, transforming, and modeling data with the goal of discovering useful information, informing
conclusions, and supporting decision-making. Data analysis has multiple facets and approaches, encompassing diverse techniques under a
variety of names, and is used in different business, science, and social science domains.
In today's business world, data analysis plays a role in making decisions more scientific and helping businesses operate more effectively
"""

# Process text
doc = nlp(data)

# Extract chunks (noun phrases)
for chunk in doc.noun_chunks:
    print("NP:", chunk.text, " | Head:", chunk.root.text, " | Label:", chunk.root.dep_)

# %% [markdown]
# ## Deep Parsing

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

data = """
Data analysis is the process of inspecting, cleansing, transforming, and modeling data with the goal of discovering useful information, informing
conclusions, and supporting decision-making. Data analysis has multiple facets and approaches, encompassing diverse techniques under a
variety of names, and is used in different business, science, and social science domains.
In today's business world, data analysis plays a role in making decisions more scientific and helping businesses operate more effectively
"""

# process the data
doc = nlp(data)

# Print dependency relations
for token in doc:
    print(f"{token.text:<15} {token.dep_:<10} {token.head.text:<15} {token.pos_}")

# Visualize one sentence as dependency tree (in Jupyter)
displacy.render(list(doc.sents)[0], style="dep", jupyter=True, options={"distance": 120})

# %% [markdown]
# ## Named Entity Recognition
# ![image.png](data:image/png;base64,...)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag, ne_chunk

# Sample data (keep capitalization)
data = """
Raman has graduated from California University of Education located at California on 24th August 2025.
"""

# Tokenize & POS tagging
word_tokens = word_tokenize(data)
pos_tags = pos_tag(word_tokens)

# Named Entity Recognition (chunking)
entities_tree = ne_chunk(pos_tags)

# Extract named entities
named_entities = []
for subtree in entities_tree:
    if hasattr(subtree, "label"):  # Check if it's a NE
        entity = " ".join([token for token, pos in subtree.leaves()])
        label = subtree.label()
        named_entities.append((entity, label))

print("Original Text:", data)
print("Named Entities:", named_entities)

# %%
# !python -m spacy download en_core_web_trf

# %%
import spacy

nlp = spacy.load("en_core_web_trf")

text = "Raman has graduated from California University of Education located at California on 24th August 2025."
doc = nlp(text)

for ent in doc.ents:
    print(ent.text, ent.label_)

# %%
content = "The little puppy was small"

# %%
word= "car"

# %%
from nltk.corpus import wordnet
