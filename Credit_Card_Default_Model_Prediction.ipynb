# %% [markdown]
# <a href="https://colab.research.google.com/github/sindhura-nk/AI-Projects---1519/blob/main/Credit_Card_Default_Model_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Credit Card Default Model prediciton using Artificial Neural Network - ANN
# ### Build a model that will predict borrowers’ chance of defaulting on credit loans.

# %% [markdown]
# Change the runtime and Connect to GPU before executing
# ![image.png](data:image/png;base64,...)

# %%
pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2026.2.25)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
default_of_credit_card_clients = fetch_ucirepo(id=350)

# data (as pandas dataframes)
X = default_of_credit_card_clients.data.features
y = default_of_credit_card_clients.data.targets

X.head()
# Out:
#        X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...    X14    X15    X16  \
# 0   20000   2   2   1  24   2   2  -1  -1   -2  ...    689      0      0
# 1  120000   2   2   2  26  -1   2   0   0    0  ...   2682   3272   3455
# 2   90000   2   2   2  34   0   0   0   0    0  ...  13559  14331  14948
# 3   50000   2   2   1  37   0   0   0   0    0  ...  49291  28314  28959
# 4   50000   1   2   1  57  -1   0  -1   0    0  ...  35835  20940  19146
#
#      X17   X18    X19    X20   X21   X22   X23
# 0      0     0    689      0     0     0     0
# 1   3261     0   1000   1000  1000     0  2000
# 2  15549  1518   1500   1000  1000  1000  5000
# 3  29547  2000   2019   1200  1100  1069  1000
# 4  19131  2000  36681  10000  9000   689   679
#
# [5 rows x 23 columns]

# %%
y.head()
# Out:
#    Y
# 0  1
# 1  1
# 2  0
# 3  0
# 4  0

# %%
new_cols = ['Credit_Amount','Gender','Education','Marital status','Age','Repay_Sept','Repay_Aug','Repay_July','Repay_June','Repay_May','Repay_April',
            'Bill_Sept','Bill_Aug','Bill_July','Bill__June','Bill_May','Bill_April',
           'Amount_paid_Sept','Amount_paid_Aug','Amount_paid_July','Amount_paid_June','Amount_paid_May','Amount_paid_April']

# %%
X.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11',
#        'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20', 'X21',
#        'X22', 'X23'],
#       dtype='object')

# %%
X.columns = new_cols
X.columns
# Out:
# Index(['Credit_Amount', 'Gender', 'Education', 'Marital status', 'Age',
#        'Repay_Sept', 'Repay_Aug', 'Repay_July', 'Repay_June', 'Repay_May',
#        'Repay_April', 'Bill_Sept', 'Bill_Aug', 'Bill_July', 'Bill__June',
#        'Bill_May', 'Bill_April', 'Amount_paid_Sept', 'Amount_paid_Aug',
#        'Amount_paid_July', 'Amount_paid_June', 'Amount_paid_May',
#        'Amount_paid_April'],
#       dtype='object')

# %%
X.head()
# Out:
#    Credit_Amount  Gender  Education  Marital status  Age  Repay_Sept  \
# 0          20000       2          2               1   24           2
# 1         120000       2          2               2   26          -1
# 2          90000       2          2               2   34           0
# 3          50000       2          2               1   37           0
# 4          50000       1          2               1   57          -1
#
#    Repay_Aug  Repay_July  Repay_June  Repay_May  ...  Bill_July  Bill__June  \
# 0          2          -1          -1         -2  ...        689           0
# 1          2           0           0          0  ...       2682        3272
# 2          0           0           0          0  ...      13559       14331
# 3          0           0           0          0  ...      49291       28314
# 4          0          -1           0          0  ...      35835       20940
#
#    Bill_May  Bill_April  Amount_paid_Sept  Amount_paid_Aug  Amount_paid_July  \
# 0         0           0                 0              689                 0
# 1      3455        3261                 0             1000              1000
# 2     14948       15549              1518             1500              1000
# 3     28959       29547              2000             2019              1200
# 4     19146       19131              2000            36681             10000
#
#    Amount_paid_June  Amount_paid_May  Amount_paid_April
# 0                 0                0                  0
# 1              1000                0               2000
# 2              1000             1000               5000
# 3              1100             1069               1000
# 4              9000              689                679
#
# [5 rows x 23 columns]

# %%
y.head()
# Out:
#    Y
# 0  1
# 1  1
# 2  0
# 3  0
# 4  0

# %%
y.value_counts()
# Out:
# Y
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
((y.value_counts())/len(y))*100
# Out:
# Y
# 0    77.88
# 1    22.12
# Name: count, dtype: float64

# %%
y.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Y'>

# %% [markdown]
# ## This dataset has imbalanced data for target features

# %%
len(y)
# Out:
# 30000

# %%
X.head(2)
# Out:
#    Credit_Amount  Gender  Education  Marital status  Age  Repay_Sept  \
# 0          20000       2          2               1   24           2
# 1         120000       2          2               2   26          -1
#
#    Repay_Aug  Repay_July  Repay_June  Repay_May  ...  Bill_July  Bill__June  \
# 0          2          -1          -1         -2  ...        689           0
# 1          2           0           0          0  ...       2682        3272
#
#    Bill_May  Bill_April  Amount_paid_Sept  Amount_paid_Aug  Amount_paid_July  \
# 0         0           0                 0              689                 0
# 1      3455        3261                 0             1000              1000
#
#    Amount_paid_June  Amount_paid_May  Amount_paid_April
# 0                 0                0                  0
# 1              1000                0               2000
#
# [2 rows x 23 columns]

# %%
X.dtypes
# Out:
# Credit_Amount        int64
# Gender               int64
# Education            int64
# Marital status       int64
# Age                  int64
# Repay_Sept           int64
# Repay_Aug            int64
# Repay_July           int64
# Repay_June           int64
# Repay_May            int64
# Repay_April          int64
# Bill_Sept            int64
# Bill_Aug             int64
# Bill_July            int64
# Bill__June           int64
# Bill_May             int64
# Bill_April           int64
# Amount_paid_Sept     int64
# Amount_paid_Aug      int64
# Amount_paid_July     int64
# Amount_paid_June     int64
# Amount_paid_May      int64
# Amount_paid_April    int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

num_pipe = make_pipeline(SimpleImputer(strategy='mean'),
                         StandardScaler()
                         ).set_output(transform='pandas')
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#    Credit_Amount    Gender  Education  Marital status       Age  Repay_Sept  \
# 0      -1.136720  0.810161   0.185828       -1.057295 -1.246020    1.794564
# 1      -0.365981  0.810161   0.185828        0.858557 -1.029047   -0.874991
# 2      -0.597202  0.810161   0.185828        0.858557 -0.161156    0.014861
# 3      -0.905498  0.810161   0.185828       -1.057295  0.164303    0.014861
# 4      -0.905498 -1.234323   0.185828       -1.057295  2.334029   -0.874991
#
#    Repay_Aug  Repay_July  Repay_June  Repay_May  ...  Bill_July  Bill__June  \
# 0   1.782348   -0.696663   -0.666599  -1.530046  ...  -0.667993   -0.672497
# 1   1.782348    0.138865    0.188746   0.234917  ...  -0.639254   -0.621636
# 2   0.111736    0.138865    0.188746   0.234917  ...  -0.482408   -0.449730
# 3   0.111736    0.138865    0.188746   0.234917  ...   0.032846   -0.232373
# 4   0.111736   -0.696663    0.188746   0.234917  ...  -0.161189   -0.346997
#
#    Bill_May  Bill_April  Amount_paid_Sept  Amount_paid_Aug  Amount_paid_July  \
# 0 -0.663059   -0.652724         -0.341942        -0.227086         -0.296801
# 1 -0.606229   -0.597966         -0.341942        -0.213588         -0.240005
# 2 -0.417188   -0.391630         -0.250292        -0.191887         -0.240005
# 3 -0.186729   -0.156579         -0.221191        -0.169361         -0.228645
# 4 -0.348137   -0.331482         -0.221191         1.335034          0.271165
#
#    Amount_paid_June  Amount_paid_May  Amount_paid_April
# 0         -0.308063        -0.314136          -0.293382
# 1         -0.244230        -0.314136          -0.180878
# 2         -0.244230        -0.248683          -0.012122
# 3         -0.237846        -0.244166          -0.237130
# 4          0.266434        -0.269039          -0.255187
#
# [5 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,y,train_size=0.7,random_state=21)

# %% [markdown]
# ## Balance the Y samples using SMOTE technique

# %%
pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (from imblearn) (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (3.6.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x_sampl,y_sampl = smote.fit_resample(xtrain,ytrain)

# %%
y_sampl.value_counts()
# Out:
# Y
# 0    16364
# 1    16364
# Name: count, dtype: int64

# %%
xtrain.shape
# Out:
# (21000, 23)

# %%
xtrain.shape[1]
# Out:
# 23

# %% [markdown]
# ## Build Neural Network model
#
# ![image.png](data:image/png;base64,...)

# %%
from keras.models import Sequential
from keras.layers import Input,Dense

# %%
# Intialize the model
model = Sequential()

# Add the Input layer
model.add(Input(shape=(xtrain.shape[1],)))

# Add the Hidden layer1
model.add(Dense(units=64,activation='relu'))

# Add the Hidden layer2
model.add(Dense(units=32,activation='relu'))

# Add the Output layer
model.add(Dense(units=1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
len(y_sampl)
# Out:
# 32728

# %%
(20*len(y_sampl))/100
# Out:
# 6545.6

# %%
nn = model.fit(x_sampl,y_sampl,validation_split=0.2,epochs=50)
# 20% trianing data is split => validation
# 20% of 32728 = used for validation
# Out:
# Epoch 1/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7223 - loss: 0.5850 - val_accuracy: 0.4581 - val_loss: 0.8611
# Epoch 2/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7412 - loss: 0.5475 - val_accuracy: 0.5189 - val_loss: 0.6957
# Epoch 3/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7467 - loss: 0.5340 - val_accuracy: 0.4849 - val_loss: 0.8242
# Epoch 4/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7494 - loss: 0.5246 - val_accuracy: 0.5053 - val_loss: 0.7528
# Epoch 5/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7534 - loss: 0.5195 - val_accuracy: 0.5373 - val_loss: 0.6992
# Epoch 6/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7471 - loss: 0.5267 - val_accuracy: 0.5237 - val_loss: 0.7662
# Epoch 7/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7488 - loss: 0.5219 - val_accuracy: 0.5816 - val_loss: 0.6740
# Epoch 8/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7568 - loss: 0.5087 - val_accuracy: 0.5194 - val_loss: 0.7653
# Epoch 9/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7542 - loss: 0.5112 - val_accuracy: 0.5128 - val_loss: 0.7734
# Epoch 10/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7560 - loss: 0.5068 - val_accuracy: 0.5484 - val_loss: 0.7423
# Epoch 11/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7547 - loss: 0.5092 - val_accuracy: 0.5318 - val_loss: 0.7298
# Epoch 12/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7497 - loss: 0.5112 - val_accuracy: 0.5057 - val_loss: 0.7909
# Epoch 13/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7585 - loss: 0.5043 - val_accuracy: 0.5498 - val_loss: 0.7170
# Epoch 14/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7559 - loss: 0.5008 - val_accuracy: 0.5046 - val_loss: 0.8272
# Epoch 15/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7642 - loss: 0.4944 - val_accuracy: 0.5634 - val_loss: 0.7079
# Epoch 16/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7618 - loss: 0.4921 - val_accuracy: 0.5883 - val_loss: 0.6722
# Epoch 17/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7577 - loss: 0.4982 - val_accuracy: 0.4812 - val_loss: 0.8713
# Epoch 18/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7636 - loss: 0.4885 - val_accuracy: 0.6150 - val_loss: 0.6754
# Epoch 19/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7580 - loss: 0.4928 - val_accuracy: 0.5642 - val_loss: 0.7069
# Epoch 20/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7633 - loss: 0.4871 - val_accuracy: 0.5581 - val_loss: 0.7035
# Epoch 21/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7692 - loss: 0.4815 - val_accuracy: 0.5877 - val_loss: 0.6861
# Epoch 22/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7699 - loss: 0.4781 - val_accuracy: 0.5918 - val_loss: 0.6670
# Epoch 23/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7685 - loss: 0.4815 - val_accuracy: 0.5617 - val_loss: 0.7313
# Epoch 24/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7679 - loss: 0.4758 - val_accuracy: 0.5849 - val_loss: 0.7006
# Epoch 25/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7725 - loss: 0.4768 - val_accuracy: 0.5988 - val_loss: 0.6679
# Epoch 26/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7694 - loss: 0.4784 - val_accuracy: 0.5501 - val_loss: 0.7354
# Epoch 27/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7727 - loss: 0.4738 - val_accuracy: 0.6101 - val_loss: 0.6369
# Epoch 28/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7752 - loss: 0.4734 - val_accuracy: 0.5655 - val_loss: 0.7218
# Epoch 29/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7693 - loss: 0.4724 - val_accuracy: 0.5881 - val_loss: 0.6908
# Epoch 30/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7742 - loss: 0.4689 - val_accuracy: 0.6036 - val_loss: 0.6910
# Epoch 31/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7750 - loss: 0.4695 - val_accuracy: 0.5952 - val_loss: 0.6767
# Epoch 32/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7746 - loss: 0.4678 - val_accuracy: 0.6460 - val_loss: 0.6052
# Epoch 33/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7756 - loss: 0.4658 - val_accuracy: 0.5929 - val_loss: 0.6670
# Epoch 34/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7755 - loss: 0.4634 - val_accuracy: 0.6361 - val_loss: 0.6098
# Epoch 35/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7747 - loss: 0.4677 - val_accuracy: 0.5840 - val_loss: 0.6927
# Epoch 36/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7774 - loss: 0.4609 - val_accuracy: 0.5973 - val_loss: 0.6768
# Epoch 37/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7788 - loss: 0.4570 - val_accuracy: 0.5544 - val_loss: 0.7645
# Epoch 38/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7811 - loss: 0.4593 - val_accuracy: 0.6260 - val_loss: 0.6364
# Epoch 39/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7793 - loss: 0.4589 - val_accuracy: 0.6438 - val_loss: 0.6134
# Epoch 40/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7835 - loss: 0.4523 - val_accuracy: 0.6442 - val_loss: 0.6331
# Epoch 41/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7878 - loss: 0.4509 - val_accuracy: 0.6056 - val_loss: 0.7049
# Epoch 42/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7821 - loss: 0.4521 - val_accuracy: 0.6467 - val_loss: 0.6192
# Epoch 43/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7818 - loss: 0.4548 - val_accuracy: 0.6051 - val_loss: 0.6858
# Epoch 44/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7830 - loss: 0.4544 - val_accuracy: 0.6777 - val_loss: 0.5677
# Epoch 45/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7874 - loss: 0.4514 - val_accuracy: 0.5791 - val_loss: 0.7253
# Epoch 46/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7836 - loss: 0.4527 - val_accuracy: 0.6848 - val_loss: 0.5853
# Epoch 47/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7884 - loss: 0.4426 - val_accuracy: 0.6412 - val_loss: 0.6265
# Epoch 48/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7936 - loss: 0.4442 - val_accuracy: 0.6019 - val_loss: 0.7133
# Epoch 49/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7909 - loss: 0.4400 - val_accuracy: 0.6054 - val_loss: 0.6761
# Epoch 50/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7891 - loss: 0.4393 - val_accuracy: 0.6969 - val_loss: 0.5512

# %% [markdown]
# ## Learning Curve

# %%
import matplotlib.pyplot as plt
plt.plot(nn.history['loss'],label='Training Loss')
plt.plot(nn.history['val_loss'],label='Validation Loss')
plt.xlabel("Number of Epochs")
plt.ylabel("Binary Cross Entropy")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %%
model.evaluate(xtest,ytest)
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7610 - loss: 0.5512
# [0.5431544184684753, 0.7591111063957214]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ypreds = model.predict(xtest)
ypreds[:10]
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# array([[0.6664157 ],
#        [0.6296559 ],
#        [0.1596571 ],
#        [0.17742987],
#        [0.0462088 ],
#        [0.28912383],
#        [0.5249327 ],
#        [0.05901795],
#        [0.78093594],
#        [0.04265005]], dtype=float32)

# %%
ytest.head()
# Out:
#        Y
# 6677   0
# 20672  1
# 19682  0
# 23589  0
# 16352  1

# %%
ypreds_new = []
for i in ypreds:
  if i>0.5:
    ypreds_new.append(1)
  else:
    ypreds_new.append(0)
ypreds_new[:10]
# Out:
# [1, 1, 0, 0, 0, 0, 1, 0, 1, 0]

# %%
ytest.value_counts()
# Out:
# Y
# 0    7000
# 1    2000
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,ypreds_new))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84      7000
#            1       0.47      0.57      0.51      2000
#
#     accuracy                           0.76      9000
#    macro avg       0.67      0.69      0.68      9000
# weighted avg       0.78      0.76      0.77      9000
